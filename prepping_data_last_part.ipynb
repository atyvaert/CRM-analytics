# %%
#-------------------------------------------------------------------------------
#-------------------------------------------------------------------------------
#Prepping visitData (HVC_HVVISITRESULT)
#-------------------------------------------------------------------------------
#-------------------------------------------------------------------------------


#Reading the file and storing each line in the list text
with open ("/Users/Artur/Desktop/uni jaar 5 sem 1/ACRM/Group assignment/Data/HVC_HVVISITRESULT.csv", "r") as f:
    textVisit = f.readlines()
textVisit.pop(0)
# Out:
# 'HVVISITRESULT_NRID;SO0_NRID;AM0_NRID;HVOUTCOME_NRID;VISITDATE;DATEONLY;AMOUNT;PAYMENTTERM\n'

# %%
#We make a dictionnary based on the data
CompanyVisitDict = {}

# %%
for e in textVisit:
    Visit_ID, Customer_ID, Employee_ID, VisitOutcome_ID, Time, Date, Amount, paymentMethod = e.replace("\n","").split(";")
    Visit_ID= int(Visit_ID)
    Customer_ID= int(Customer_ID)
    Employee_ID= int(Employee_ID)
    VisitOutcome_ID= int(VisitOutcome_ID)
    Amount= float(Amount)
    CompanyVisitDict[Visit_ID]= {"Customer_ID":Customer_ID,"Employee_ID": Employee_ID, "VisitOutcome_ID": VisitOutcome_ID, "Time": Time,"Date": Date, "Amount": Amount, "paymentMethod": paymentMethod }

# %%
#Some visits do not have a payment method recorded: We set the paymentMethod of these cases to the None variable
#Maybe these missing values will have value later on
for e in CompanyVisitDict:
    P_method = CompanyVisitDict[e]["paymentMethod"]
    if(P_method == ""):
        CompanyVisitDict[e]["paymentMethod"]= None

# %%
#-------------------------------------------------------------------------------
#-------------------------------------------------------------------------------
#Prepping EmployeeData (HVC_SO0)
#-------------------------------------------------------------------------------
#-------------------------------------------------------------------------------


#Reading the file and storing each line in the list text
with open ("/Users/Artur/Desktop/uni jaar 5 sem 1/ACRM/Group assignment/Data/HVC_SO0.csv", "r") as f:
    textCustomerType = f.readlines()
textCustomerType.pop(0)
# Out:
# 'SO0_NRID;HVROUTETEMPLATE_NRID;CUST_TYPE;POSTCODE;LANGUAGE;SEASON_TYPE\n'

# %%
#We make a dictionnary based on the data
CustomerTypeDict = {}

# %%
for e in textCustomerType:
    Customer_ID, RouteTemplate_ID, CustomerType, Postcode, Language, Season = e.replace("\n","").split(";")
    Customer_ID=int(float(Customer_ID))
    RouteTemplate_ID=int(float(RouteTemplate_ID))
    CompanyVisitDict[Customer_ID]= {"RouteTemplate_ID":RouteTemplate_ID,"CustomerType": CustomerType, "Postcode": Postcode, "Language": Language,"Season": Season}

# %%
print(CustomerTypeDict)
# Out:
# {}

# %%
#-------------------------------------------------------------------------------
#-------------------------------------------------------------------------------
#Prepping ProductData (HVC_VISITRESULTDETAILS)
#-------------------------------------------------------------------------------
#-------------------------------------------------------------------------------


with open ("/Users/Artur/Desktop/uni jaar 5 sem 1/acrm/group assignment/Data/HVC_VISITRESULTDETAILS.csv", "r") as f:
    textVisitDetails = f.readlines()
textVisitDetails.pop(0)
# Out:
# 'VISITRESULTDETAILS_NRID;AR0_NRID;QUANTITY;HVVISITRESULT_NRID\n'

# %%
#We make a dictionnary based on the data
VisitDetailsDict = {}

# %%
for e in textVisitDetails:
    VisitDetails_ID, Product_ID, Quantity, Visit_ID = e.replace("\n","").split(";")
    VisitDetails_ID=int(VisitDetails_ID)
    Quantity=int(float(Quantity))
    Visit_ID=int(float(Visit_ID))
    CompanyVisitDict[VisitDetails_ID]= {"Product_ID":Product_ID,"Quantity": Quantity, "Visit_ID": Visit_ID, "Language": Language,"Season": Season}

# %%
print(VisitDetailsDict)
# Out:
# {}

# %%
with open ("/Users/Artur/Desktop/uni jaar 5 sem 1/acrm/group assignment/Data/HVC_CUSTOMER_REVIEWS.csv", "r") as f:
    textCustReviews = f.readlines()
textCustReviews.pop(0)

CompanyReviewsDict = {}
for e in textCustReviews:
    CustomerID, Review  = e.replace("\n","").split(";")
    CustomerID = int(CustomerID)
    CompanyReviewsDict[CustomerID]= {"Review": Review}

print(CompanyReviewsDict)
# Out:
# {719952: {'Review': 'Good service, satisfied'}, 1453609: {'Review': 'No opinion'}, 1453614: {'Review': 'No opinion'}, 1453602: {'Review': 'Excellent service, very satisfied'}, 1252497: {'Review': 'No opinion'}, 1400065: {'Review': 'No opinion'}, 719546: {'Review': 'Good service, satisfied'}, 21013060504838: {'Review': 'Not completely satisfied'}, 22733168394242: {'Review': 'Good service, satisfied'}, 21494752587036: {'Review': 'Good service, satisfied'}, 1252933: {'Review': 'Good service, satisfied'}, 1246518: {'Review': 'Good service, satisfied'}, 21511356114642: {'Review': 'Good service, satisfied'}, 1251879: {'Review': 'Excellent service, very satisfied'}, 1246540: {'Review': 'Good service, satisfied'}, 1251884: {'Review': 'No opinion'}, 1246529: {'Review': 'No opinion'}, 1246550: {'Review': 'Good service, satisfied'}, 1246556: {'Review': 'Good service, satisfied'}, 21444856404640: {'Review': 'Good service, satisfied'}, 1246568: {'Review': 'Good service, satisfied'}, 1251889: {'Review': 'Good service, satisfied'}, 1251894: {'Review': 'Good service, satisfied'}, 1246043: {'Review': 'No opinion'}, 725503: {'Review': 'Good service, satisfied'}, 1246000: {'Review': 'Good service, satisfied'}, 720057: {'Review': 'No opinion'}, 1453722: {'Review': 'No opinion'}, 726792: {'Review': 'Good service,